# %%
n, bins, patches = plt.hist(sample, density=True, histtype='step',
                           cumulative=True, label='Empirical')

# %%
y = (np.exp(-(np.log(x) - mu)**2 / (2 * sigma2))/(x * np.sqrt(sigma2) * np.sqrt(2 * np.pi)))
y=y.cumsum()
y /= y[-1]

plt.hist(sample, density=True, histtype='step', cumulative=True, label='Empirical')
plt.plot(x, y, 'r--', linewidth=1.5, label='Theoretical')
plt.show()
